# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/10820231/flower_growth_data.csv")

# %%
df.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  -0.560976   4.204277  -2.476417  -1.565151  -0.143334   1.678436
# 1  -1.266290   4.336719  -2.085581  -1.433073   0.277317   0.815580
# 2  -1.026664   4.341302  -0.912544  -1.290386  -0.415658   1.481430
# 3  -1.491347   4.339637  -0.616179  -0.017116   0.331507   1.928570
# 4  -1.328909   4.557485  -0.092849  -2.303006   0.139155  -0.047013
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_991  feature_992  \
# 0   1.260787   2.502113   2.664278  -0.198266  ...     0.396983    -1.280882
# 1   1.223473   2.826873   2.645914  -0.478923  ...     1.199642    -1.368839
# 2   1.078927   3.128834   3.667993   1.598565  ...     1.230363    -0.711245
# 3   2.105180   3.040951   2.378275   0.739959  ...     1.029347    -0.784429
# 4   0.063455   1.915573   2.892002   0.330211  ...     2.008244    -1.032403
#
#    feature_993  feature_994  feature_995  feature_996  feature_997  \
# ...

# %%
df['timestamp'].value_counts()
# Out:
# 14.0    1
# 28.0    1
# 29.0    1
# 19.0    1
# 8.0     1
# 6.0     1
# 16.0    1
# 22.0    1
# 1.0     1
# 17.0    1
# 11.0    1
# 2.0     1
# 18.0    1
# 27.0    1
# 20.0    1
# 5.0     1
# 10.0    1
# 30.0    1
# 26.0    1
# 13.0    1
# 7.0     1
# 3.0     1
# 15.0    1
# 12.0    1
# 23.0    1
# 4.0     1
# 24.0    1
# 21.0    1
# 25.0    1
# 9.0     1
# Name: timestamp, dtype: int64

# %%
df.shape
# Out:
# (30, 1001)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
X = df['feature_0']
y = df['timestamp']
degree = 14

coeff = np.polyfit(X,y, deg = degree)
line = np.poly1d(coeff)
x_fit = np.linspace(X.min(), X.max(), 50)
y_fit = line(x_fit)

plt.scatter(X, y, label='Feature 0')
plt.plot(x_fit, y_fit, 'r', label=f'Fitted Polynomial (Degree {degree})')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Fitting')
plt.show()

# %%
X = df['feature_0']
y = df['timestamp']
degree = 8

coeff = np.polyfit(X,y, deg = degree)
line = np.poly1d(coeff)
x_fit = np.linspace(X.min(), X.max(), 50)
y_fit = line(x_fit)

plt.scatter(X, y, label='Feature 0')
plt.plot(x_fit, y_fit, 'r', label=f'Fitted Polynomial (Degree {degree})')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Fitting')
plt.show()

# %%
X = df['feature_0']
y = df['timestamp']
degree = 4

coeff = np.polyfit(X,y, deg = degree)
line = np.poly1d(coeff)
x_fit = np.linspace(X.min(), X.max(), 50)
y_fit = line(x_fit)

plt.scatter(X, y, label='Feature 0')
plt.plot(x_fit, y_fit, 'r', label=f'Fitted Polynomial (Degree {degree})')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Fitting')
plt.show()

# %%
X = df['feature_0']
y = df['timestamp']
degree = 2

coeff = np.polyfit(X,y, deg = degree)
line = np.poly1d(coeff)
x_fit = np.linspace(X.min(), X.max(), 50)
y_fit = line(x_fit)

plt.scatter(X, y, label='Feature 0')
plt.plot(x_fit, y_fit, 'r', label=f'Fitted Polynomial (Degree {degree})')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Fitting')
plt.show()

# %%
X = df['feature_1']
y = df['timestamp']
degree = 2

coeff = np.polyfit(X,y, deg = degree)
line = np.poly1d(coeff)
x_fit = np.linspace(X.min(), X.max(), 50)
y_fit = line(x_fit)

plt.scatter(X, y, label='Feature 1')
plt.plot(x_fit, y_fit, 'r', label=f'Fitted Polynomial (Degree {degree})')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Fitting')
plt.show()

# %%
X = df['feature_1']
y = df['timestamp']
degree = 4

coeff = np.polyfit(X,y, deg = degree)
line = np.poly1d(coeff)
x_fit = np.linspace(X.min(), X.max(), 50)
y_fit = line(x_fit)

plt.scatter(X, y, label='Feature 1')
plt.plot(x_fit, y_fit, 'r', label=f'Fitted Polynomial (Degree {degree})')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Fitting')
plt.show()

# %%
X = df['feature_1']
y = df['timestamp']
degree = 12

coeff = np.polyfit(X,y, deg = degree)
line = np.poly1d(coeff)
x_fit = np.linspace(X.min(), X.max(), 50)
y_fit = line(x_fit)

plt.scatter(X, y, label='Feature 1')
plt.plot(x_fit, y_fit, 'r', label=f'Fitted Polynomial (Degree {degree})')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Fitting')
plt.show()
